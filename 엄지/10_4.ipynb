# %% [markdown]
# <a href="https://colab.research.google.com/github/SH22Hwang/GNU_AugumentedIntelligenceLab/blob/main/%EC%97%84%EC%A7%80/10_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf

# %%
size, seq_len = 100, 3

X = np.empty(shape=(size, seq_len, 1))
Y = np.empty(shape=(size,))

for i in range(size):
  c = np.linspace(i/10., (i+seq_len-1)/10., seq_len)
  X[i] = c[:, np.newaxis]
  Y[i] = (i+seq_len) / 10

for i in range(len(X)):
  print(X[i], Y[i])
# Out:
# [[0. ]
#  [0.1]
#  [0.2]] 0.3
# [[0.1]
#  [0.2]
#  [0.3]] 0.4
# [[0.2]
#  [0.3]
#  [0.4]] 0.5
# [[0.3]
#  [0.4]
#  [0.5]] 0.6
# [[0.4]
#  [0.5]
#  [0.6]] 0.7
# [[0.5]
#  [0.6]
#  [0.7]] 0.8
# [[0.6]
#  [0.7]
#  [0.8]] 0.9
# [[0.7]
#  [0.8]
#  [0.9]] 1.0
# [[0.8]
#  [0.9]
#  [1. ]] 1.1
# [[0.9]
#  [1. ]
#  [1.1]] 1.2
# [[1. ]
#  [1.1]
#  [1.2]] 1.3
# [[1.1]
#  [1.2]
#  [1.3]] 1.4
# [[1.2]
#  [1.3]
#  [1.4]] 1.5
# [[1.3]
#  [1.4]
#  [1.5]] 1.6
# [[1.4]
#  [1.5]
#  [1.6]] 1.7
# [[1.5]
#  [1.6]
#  [1.7]] 1.8
# [[1.6]
#  [1.7]
#  [1.8]] 1.9
# [[1.7]
#  [1.8]
#  [1.9]] 2.0
# [[1.8]
#  [1.9]
#  [2. ]] 2.1
# [[1.9]
#  [2. ]
#  [2.1]] 2.2
# [[2. ]
#  [2.1]
#  [2.2]] 2.3
# [[2.1]
#  [2.2]
#  [2.3]] 2.4
# [[2.2]
#  [2.3]
#  [2.4]] 2.5
# [[2.3]
#  [2.4]
#  [2.5]] 2.6
# [[2.4]
#  [2.5]
#  [2.6]] 2.7
# [[2.5]
#  [2.6]
#  [2.7]] 2.8
# [[2.6]
#  [2.7]
#  [2.8]] 2.9
# [[2.7]
#  [2.8]
#  [2.9]] 3.0
# [[2.8]
#  [2.9]
#  [3. ]] 3.1
# [[2.9]
#  [3. ]
#  [3.1]] 3.2
# [[3. ]
#  [3.1]
#  [3.2]] 3.3
# ...

# %%
model = tf.keras.Sequential([tf.keras.layers.SimpleRNN(units=20, return_sequences=False, input_shape=[3,1]), tf.keras.layers.Dense(1)])

# %%
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn (SimpleRNN)       (None, 20)                440
# _________________________________________________________________
# dense (Dense)                (None, 1)                 21
# ...
# Total params: 461
# Trainable params: 461
# Non-trainable params: 0
# _________________________________________________________________

# %%
model = tf.keras.Sequential([tf.keras.layers.SimpleRNN(units=20, return_sequences=False, input_shape=[seq_len, 2]), tf.keras.layers.Dense(1)])

# %%
model.compile(optimizer='adam', loss='mse')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# simple_rnn_1 (SimpleRNN)     (None, 20)                460
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 21
# ...
# Total params: 481
# Trainable params: 481
# Non-trainable params: 0
# _________________________________________________________________
