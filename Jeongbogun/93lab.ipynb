# %% [markdown]
# <a href="https://colab.research.google.com/github/SH22Hwang/GNU_AugumentedIntelligenceLab/blob/SH22Hwang-patch-1/Jeongbogun/93lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from skimage.transform import resize
from keras.applications.inception_v3 import preprocess_input
from keras.applications.inception_v3 import InceptionV3
from keras import models, layers
from keras.models import Model, load_model
import pandas as pd
#from keras.optimizers import RMSprop
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-aafb49d8d867> in <module>()
#       8 from keras.models import Model, load_model
#       9 import pandas as pd
# ---> 10 from keras.optimizers import RMSprop
#
# ImportError: cannot import name 'RMSprop' from 'keras.optimizers' (/usr/local/lib/python3.7/dist-packages/keras/optimizers.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
mnist = tf.keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load.data()
x_train, x_test = x_train[:10000] / 255.0, x_test[:2000]/255.0
y_train, y_test = y_train[:10000], y_test[:2000]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-463f2e88447c> in <module>()
#       1 mnist = tf.keras.datasets.mnist
# ----> 2 (x_train, y_train), (x_test, y_test) = mnist.load.data()
#       3 x_train, x_test = x_train[:10000] / 255.0, x_test[:2000]/255.0
#       4 y_train, y_test = y_train[:10000], y_test[:2000]
#
# AttributeError: module 'keras.api._v2.keras.datasets.mnist' has no attribute 'load'

# %%
x_train_preprocess = np.zeros((x_train.shape[0],75,75,3),
                              dtype=np.float32)
print(x_train_preprocess.shape)

for i, img in enumerate(x_train):
  img_resize = resize(img, (75,75), anti_aliasing=True)
  x_train_preprocess[i] = np.dstack([img_resize,img_resize,img_resize])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6466fd075b7a> in <module>()
# ----> 1 x_train_preprocess = np.zeros((x_train.shape[0],75,75,3),
#       2                               dtype=np.float32)
#       3 print(x_train_preprocess.shape)
#       4
#       5 for i, img in enumerate(x_train):
#
# NameError: name 'x_train' is not defined

# %%
x_test_preprocess = np.zeros((x_test.shape[0],75,75,3),
                              dtype=np.float32)
print(x_test_preprocess.shape)

for i, img in enumerate(x_test):
  img_resize = resize(img, (75,75), anti_aliasing=True)
  x_test_preprocess[i] = np.dstack([img_resize,img_resize,img_resize])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-47ab1d7ce409> in <module>()
# ----> 1 x_test_preprocess = np.zeros((x_test.shape[0],75,75,3),
#       2                               dtype=np.float32)
#       3 print(x_test_preprocess.shape)
#       4
#       5 for i, img in enumerate(x_test):
#
# NameError: name 'x_test' is not defined

# %%
pre_trained_model = InceptionV3(input_shape=(75,75,3),
                                include_top=False,
                                weights=None)
pre_trained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_1 (InputLayer)            [(None, 75, 75, 3)]  0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 37, 37, 32)   864         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 37, 37, 32)   96          conv2d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 37, 37, 32)   0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# ...

# %%
last_layer = pre_trained_model.get_layer('mixed7')
last_output = last_layer.output

x = layers.Flatten()(last_output)
x = layers.Dense(1024, activation='relu')(x)
x = layers.Dense(10, activation='sigmoid')(x)

# %%
model = Model(pre_trained_model.input,x)

model.compile(optimizer=RMSprop(lr=0.001),
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-0e13a2c536d2> in <module>()
#       1 model = Model(pre_trained_model.input,x)
#       2
# ----> 3 model.compile(optimizer=RMSprop(lr=0.001),
#       4               loss='sparse_categorical_crossentropy',
#       5               metrics=['accuracy'])
#
# NameError: name 'RMSprop' is not defined

# %%
history = model.fit(x_train_preprocess, y_train, epochs=20,
                    validation_data=(x_test_preprocess, y_test))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-1b33b3c4867d> in <module>()
# ----> 1 history = model.fit(x_train_preprocess, y_train, epochs=20,
#       2                     validation_data=(x_test_preprocess, y_test))
#
# NameError: name 'x_train_preprocess' is not defined

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-ca10813e8ed9> in <module>()
# ----> 1 acc = history.history['accuracy']
#       2 val_acc = history.history['val_accuracy']
#       3 loss = history.history['loss']
#       4 val_loss = history.history['val_loss']
#       5
#
# NameError: name 'history' is not defined

# %%
plt.plot(epochs, acc, 'r', label = 'Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title("Mnist Training accuracy")
plt.legend(loc=0)
plt.figure()
plt.show()
plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title("Mnist Training loss")
plt.legend(loc=0)
plt.figure()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-7fa5557854a9> in <module>()
# ----> 1 plt.plot(epochs, acc, 'r', label = 'Training accuracy')
#       2 plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
#       3 plt.title("Mnist Training accuracy")
#       4 plt.legend(loc=0)
#       5 plt.figure()
#
# NameError: name 'epochs' is not defined
